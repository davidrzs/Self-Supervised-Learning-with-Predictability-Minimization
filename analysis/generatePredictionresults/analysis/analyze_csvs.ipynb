# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob
from pathlib import Path


import seaborn as sns

# %%
def correlation_sum(corr_mat):
    assert corr_mat.shape[0] == corr_mat.shape[1]
    corr_mat_abs = np.absolute(corr_mat)
    sums = np.sum(corr_mat_abs, axis=1) - corr_mat_abs.diagonal() # axis doen't matter
    sums /= (corr_mat.shape[0]-1)
    return sums

# %%
# find all folders in the 'correlation_analysis' folder
# for every folder we extract the path, the model name, the wandb run id and the number and end up creating a dataframe
all_folders = glob.glob('correlation_analysis/*')

all_data = pd.DataFrame(columns=['path', 'model_name', 'dataset_name', 'data_split', 'wandb_run_id', 'num', 'corr_sum'])



for folder in all_folders:
    path = Path(folder)
    model_name = path.name
    model_name = model_name.split('-')[0]
    dataset_name = path.name.split('-')[1].split('_')[0]
    data_split = path.name.split('_')[-1]
    wandb_run_id = path.name.split('_')[-2]
    
    # print(path, model_name, dataset_name, data_split, wandb_run_id)
    all_data.loc[len(all_data)] = [path, model_name, dataset_name, data_split, wandb_run_id, 0, 0]
        
all_data
# Out:
#                                                   path model_name  \
# 0    correlation_analysis/vicreg-imagenet100_pxqwg3...     vicreg
# 1    correlation_analysis/vicreg-imagenet100_pxqwg3...     vicreg
# 2    correlation_analysis/vicreg-cifar100_000hudwm_...     vicreg
# 3    correlation_analysis/vicreg-cifar100_000hudwm_val     vicreg
# 4    correlation_analysis/vicreg-cifar100_31yfnww4_...     vicreg
# ..                                                 ...        ...
# 119  correlation_analysis/simclr-cifar100_3kh01qs8_val     simclr
# 120  correlation_analysis/simclr-cifar10_y6674tsl_t...     simclr
# 121   correlation_analysis/simclr-cifar10_y6674tsl_val     simclr
# 122  correlation_analysis/simclr-cifar100_5dgztcwi_...     simclr
# 123  correlation_analysis/simclr-cifar100_5dgztcwi_val     simclr
#
#     dataset_name data_split wandb_run_id  num  corr_sum
# 0    imagenet100      train     pxqwg3ex    0         0
# 1    imagenet100        val     pxqwg3ex    0         0
# 2       cifar100      train     000hudwm    0         0
# 3       cifar100        val     000hudwm    0         0
# 4       cifar100      train     31yfnww4    0         0
# ..           ...        ...          ...  ...       ...
# 119     cifar100        val     3kh01qs8    0         0
# 120      cifar10      train     y6674tsl    0         0
# 121      cifar10        val     y6674tsl    0         0
# 122     cifar100      train     5dgztcwi    0         0
# 123     cifar100        val     5dgztcwi    0         0
#
# [124 rows x 7 columns]

# %%
# for every entry in the dataframe we load the dataframe and calculate the correlation sum
for index, row in all_data.iterrows():
    final_path = row['path']/Path('correlation.csv')
    print(final_path)
    df = pd.read_csv(final_path)

    corr_mat = df.to_numpy()
    corr_sum = np.nanmean(corr_mat)
    all_data.loc[index, 'corr_sum'] = corr_sum
    all_data.loc[index, 'num'] = corr_mat.shape[0]

# barlow_train = pd.read_csv('../cifar10_-home-david-Downloads-dye9qi27_train_corr.csv',header=None)
# barlow_val = pd.read_csv('../cifar10_-home-david-Downloads-dye9qi27_val_corr.csv',header=None)

# lin_pred_min_train = pd.read_csv('../cifar10_-home-david-Downloads-gqvmpfko_train_corr.csv',header=None)
# lin_pred_min_val = pd.read_csv('../cifar10_-home-david-Downloads-gqvmpfko_val_corr.csv',header=None)
# Out:
# correlation_analysis/vicreg-imagenet100_pxqwg3ex_train/correlation.csv
# correlation_analysis/vicreg-imagenet100_pxqwg3ex_val/correlation.csv
# correlation_analysis/vicreg-cifar100_000hudwm_train/correlation.csv
# correlation_analysis/vicreg-cifar100_000hudwm_val/correlation.csv
# correlation_analysis/vicreg-cifar100_31yfnww4_train/correlation.csv
# correlation_analysis/vicreg-cifar100_31yfnww4_val/correlation.csv
# correlation_analysis/vicreg-imagenet100_ihgpptnq_train/correlation.csv
# correlation_analysis/vicreg-imagenet100_ihgpptnq_val/correlation.csv
# correlation_analysis/vicreg-cifar10_ko7v7xmw_train/correlation.csv
# correlation_analysis/vicreg-cifar10_ko7v7xmw_val/correlation.csv
# correlation_analysis/vicreg-cifar10_oapd6xab_train/correlation.csv
# correlation_analysis/vicreg-cifar10_oapd6xab_val/correlation.csv
# correlation_analysis/cl_lin_pred_min-imagenet100_4450okxr_train/correlation.csv
# correlation_analysis/cl_lin_pred_min-imagenet100_4450okxr_val/correlation.csv
# correlation_analysis/cl_lin_pred_min-imagenet100_x6p8gwro_train/correlation.csv
# correlation_analysis/cl_lin_pred_min-imagenet100_x6p8gwro_val/correlation.csv
# correlation_analysis/cl_lin_pred_min-imagenet100_vkd2mvlc_train/correlation.csv
# correlation_analysis/cl_lin_pred_min-imagenet100_vkd2mvlc_val/correlation.csv
# correlation_analysis/cl_lin_pred_min-imagenet100_25jyy5nv_train/correlation.csv
# correlation_analysis/cl_lin_pred_min-imagenet100_25jyy5nv_val/correlation.csv
# correlation_analysis/cl_lin_pred_min-imagenet100_3f0e8iva_train/correlation.csv
# correlation_analysis/cl_lin_pred_min-imagenet100_3f0e8iva_val/correlation.csv
# correlation_analysis/cl_lin_pred_min-imagenet100_eoavbqp6_train/correlation.csv
# correlation_analysis/cl_lin_pred_min-imagenet100_eoavbqp6_val/correlation.csv
# correlation_analysis/cl_lin_pred_min-cifar10_jmp2p663_train/correlation.csv
# correlation_analysis/cl_lin_pred_min-cifar10_jmp2p663_val/correlation.csv
# correlation_analysis/cl_lin_pred_min-imagenet100_th5iye5v_train/correlation.csv
# correlation_analysis/cl_lin_pred_min-imagenet100_th5iye5v_val/correlation.csv
# correlation_analysis/cl_lin_pred_min-imagenet100_wgv332i9_train/correlation.csv
# correlation_analysis/cl_lin_pred_min-imagenet100_wgv332i9_val/correlation.csv
# correlation_analysis/cl_lin_pred_min-imagenet100_ndf0kggr_train/correlation.csv
# correlation_analysis/cl_lin_pred_min-imagenet100_ndf0kggr_val/correlation.csv
# correlation_analysis/cl_lin_pred_min-imagenet100_ediltapt_train/correlation.csv
# correlation_analysis/cl_lin_pred_min-imagenet100_ediltapt_val/correlation.csv
# correlation_analysis/cl_lin_pred_min-imagenet100_cej8x0bm_train/correlation.csv
# correlation_analysis/cl_lin_pred_min-imagenet100_cej8x0bm_val/correlation.csv
# correlation_analysis/cl_lin_pred_min-cifar10_0f1kbywn_train/correlation.csv
# correlation_analysis/cl_lin_pred_min-cifar10_0f1kbywn_val/correlation.csv
# correlation_analysis/cl_lin_pred_min-imagenet100_t7e941rb_train/correlation.csv
# correlation_analysis/cl_lin_pred_min-imagenet100_t7e941rb_val/correlation.csv
# correlation_analysis/cl_lin_pred_min-imagenet100_c7vzbg9t_train/correlation.csv
# correlation_analysis/cl_lin_pred_min-imagenet100_c7vzbg9t_val/correlation.csv
# correlation_analysis/cl_lin_pred_min-cifar10_2ji3gyu1_train/correlation.csv
# correlation_analysis/cl_lin_pred_min-cifar10_2ji3gyu1_val/correlation.csv
# correlation_analysis/cl_lin_pred_min-imagenet100_znm1ny4g_train/correlation.csv
# correlation_analysis/cl_lin_pred_min-imagenet100_znm1ny4g_val/correlation.csv
# correlation_analysis/cl_lin_pred_min-cifar100_6ri2n99z_train/correlation.csv
# correlation_analysis/cl_lin_pred_min-cifar100_6ri2n99z_val/correlation.csv
# correlation_analysis/cl_lin_pred_min-imagenet100_rq3fl24b_train/correlation.csv
# correlation_analysis/cl_lin_pred_min-imagenet100_rq3fl24b_val/correlation.csv
# correlation_analysis/cl_lin_pred_min-imagenet100_b6a1rjjd_train/correlation.csv
# correlation_analysis/cl_lin_pred_min-imagenet100_b6a1rjjd_val/correlation.csv
# correlation_analysis/cl_lin_pred_min-imagenet100_cw2gznyp_train/correlation.csv
# correlation_analysis/cl_lin_pred_min-imagenet100_cw2gznyp_val/correlation.csv
# correlation_analysis/cl_lin_pred_min-imagenet100_czl1e2vs_train/correlation.csv
# correlation_analysis/cl_lin_pred_min-imagenet100_czl1e2vs_val/correlation.csv
# correlation_analysis/cl_lin_pred_min-cifar10_fko9gigm_train/correlation.csv
# correlation_analysis/cl_lin_pred_min-cifar10_fko9gigm_val/correlation.csv
# correlation_analysis/cl_lin_pred_min-imagenet100_5lpx244e_train/correlation.csv
# correlation_analysis/cl_lin_pred_min-imagenet100_5lpx244e_val/correlation.csv
# correlation_analysis/mocov3-imagenet100_62kaptx2_train/correlation.csv
# correlation_analysis/mocov3-imagenet100_62kaptx2_val/correlation.csv
# correlation_analysis/mocov3-cifar10_d3e2qopt_train/correlation.csv
# correlation_analysis/mocov3-cifar10_d3e2qopt_val/correlation.csv
# correlation_analysis/mocov3-cifar100_f2sw89sq_train/correlation.csv
# correlation_analysis/mocov3-cifar100_f2sw89sq_val/correlation.csv
# correlation_analysis/mocov3-imagenet100_1vnlapw9_train/correlation.csv
# correlation_analysis/mocov3-imagenet100_1vnlapw9_val/correlation.csv
# correlation_analysis/mocov3-cifar100_6ctmjq2e_train/correlation.csv
# correlation_analysis/mocov3-cifar100_6ctmjq2e_val/correlation.csv
# correlation_analysis/mocov3-cifar10_onqz6ldk_train/correlation.csv
# correlation_analysis/mocov3-cifar10_onqz6ldk_val/correlation.csv
# correlation_analysis/barlow_twins-imagenet100_439p1boi_train/correlation.csv
# correlation_analysis/barlow_twins-imagenet100_439p1boi_val/correlation.csv
# correlation_analysis/barlow_twins-cifar10_66w0odub_train/correlation.csv
# correlation_analysis/barlow_twins-cifar10_66w0odub_val/correlation.csv
# correlation_analysis/barlow_twins-cifar10_my30vqpk_train/correlation.csv
# correlation_analysis/barlow_twins-cifar10_my30vqpk_val/correlation.csv
# correlation_analysis/barlow_twins-cifar100_gkyyt0r7_train/correlation.csv
# correlation_analysis/barlow_twins-cifar100_gkyyt0r7_val/correlation.csv
# correlation_analysis/barlow_twins-imagenet100_mw1brkzw_train/correlation.csv
# correlation_analysis/barlow_twins-imagenet100_mw1brkzw_val/correlation.csv
# correlation_analysis/barlow_twins-cifar100_krn1yxsb_train/correlation.csv
# correlation_analysis/barlow_twins-cifar100_krn1yxsb_val/correlation.csv
# correlation_analysis/vibcreg-cifar100_3ih3ejt3_train/correlation.csv
# correlation_analysis/vibcreg-cifar100_3ih3ejt3_val/correlation.csv
# correlation_analysis/vibcreg-cifar10_4zre6v8l_train/correlation.csv
# correlation_analysis/vibcreg-cifar10_4zre6v8l_val/correlation.csv
# correlation_analysis/vibcreg-imagenet100_hbjjmktg_train/correlation.csv
# correlation_analysis/vibcreg-imagenet100_hbjjmktg_val/correlation.csv
# correlation_analysis/vibcreg-imagenet100_9tjxisb5_train/correlation.csv
# correlation_analysis/vibcreg-imagenet100_9tjxisb5_val/correlation.csv
# correlation_analysis/vibcreg-cifar100_6lxrq5la_train/correlation.csv
# correlation_analysis/vibcreg-cifar100_6lxrq5la_val/correlation.csv
# correlation_analysis/vibcreg-cifar10_t4i239rs_train/correlation.csv
# correlation_analysis/vibcreg-cifar10_t4i239rs_val/correlation.csv
# correlation_analysis/byol-cifar10_5n852aih_train/correlation.csv
# correlation_analysis/byol-cifar10_5n852aih_val/correlation.csv
# correlation_analysis/byol-imagenet100_9b5fuzbl_train/correlation.csv
# correlation_analysis/byol-imagenet100_9b5fuzbl_val/correlation.csv
# correlation_analysis/byol-cifar100_1myzhgng_train/correlation.csv
# correlation_analysis/byol-cifar100_1myzhgng_val/correlation.csv
# correlation_analysis/byol-cifar10_lrw9nxzu_train/correlation.csv
# correlation_analysis/byol-cifar10_lrw9nxzu_val/correlation.csv
# correlation_analysis/byol-cifar100_fnnlb6qc_train/correlation.csv
# correlation_analysis/byol-cifar100_fnnlb6qc_val/correlation.csv
# correlation_analysis/byol-imagenet100_x8lhg4g8_train/correlation.csv
# correlation_analysis/byol-imagenet100_x8lhg4g8_val/correlation.csv
# correlation_analysis/nnclr-cifar100_a5bvf8l3_train/correlation.csv
# correlation_analysis/nnclr-cifar100_a5bvf8l3_val/correlation.csv
# correlation_analysis/nnclr-cifar10_kkuyrw9p_train/correlation.csv
# correlation_analysis/nnclr-cifar10_kkuyrw9p_val/correlation.csv
# correlation_analysis/nnclr-imagenet100_wrm9s3ze_train/correlation.csv
# correlation_analysis/nnclr-imagenet100_wrm9s3ze_val/correlation.csv
# correlation_analysis/simclr-cifar10_48rjp6ao_train/correlation.csv
# correlation_analysis/simclr-cifar10_48rjp6ao_val/correlation.csv
# correlation_analysis/simclr-imagenet100_pel8yiix_train/correlation.csv
# correlation_analysis/simclr-imagenet100_pel8yiix_val/correlation.csv
# correlation_analysis/simclr-cifar100_3kh01qs8_train/correlation.csv
# correlation_analysis/simclr-cifar100_3kh01qs8_val/correlation.csv
# correlation_analysis/simclr-cifar10_y6674tsl_train/correlation.csv
# correlation_analysis/simclr-cifar10_y6674tsl_val/correlation.csv
# correlation_analysis/simclr-cifar100_5dgztcwi_train/correlation.csv
# correlation_analysis/simclr-cifar100_5dgztcwi_val/correlation.csv

# %%
# 


# for dataset in all_data['dataset_name'].unique():
#     df = all_data[all_data['dataset_name'] == dataset]
#     df = df.sort_values(by=['model_name'])
#     plt.figure(figsize=(20,10))
#     ax = sns.barplot(x="model_name", y="corr_sum", data=df)
#     ax.set_title(dataset)
#     ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
#     plt.show()
sns.set_theme(style="whitegrid")
g = sns.catplot(x="model_name", y="corr_sum", col="dataset_name", hue="data_split",data=all_data, kind="bar")
# make x-axis labels vertical
g.set_xticklabels(rotation=45)
# Out:
# /home/david/.local/share/virtualenvs/Self-Supervised-Learning-with-Predictabili-RPXJKYD0/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
all_data[all_data['model_name'] == 'vibcreg']['path']
# Out:
# 84    correlation_analysis/vibcreg-cifar100_3ih3ejt3...
# 85    correlation_analysis/vibcreg-cifar100_3ih3ejt3...
# 86    correlation_analysis/vibcreg-cifar10_4zre6v8l_...
# 87    correlation_analysis/vibcreg-cifar10_4zre6v8l_val
# 88    correlation_analysis/vibcreg-imagenet100_hbjjm...
# 89    correlation_analysis/vibcreg-imagenet100_hbjjm...
# 90    correlation_analysis/vibcreg-imagenet100_9tjxi...
# 91    correlation_analysis/vibcreg-imagenet100_9tjxi...
# 92    correlation_analysis/vibcreg-cifar100_6lxrq5la...
# 93    correlation_analysis/vibcreg-cifar100_6lxrq5la...
# 94    correlation_analysis/vibcreg-cifar10_t4i239rs_...
# 95    correlation_analysis/vibcreg-cifar10_t4i239rs_val
# Name: path, dtype: object
